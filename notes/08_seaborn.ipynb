# %% [markdown]
# ## 08.🌊Seaborn
# - Matplotlib 기반의 시각화 라이브러리
# - 통계 데이터 시각화에 특화(Pandas와 연계 좋음)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.__version__
# Out:
# '0.13.2'

# %%
# 사용 가능한 데이터셋 이름 출력
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
# 데이터셋 로드
df = sns.load_dataset("planets")
df.head(10)
# Out:
#             method  number  orbital_period   mass  distance  year
# 0  Radial Velocity       1         269.300   7.10     77.40  2006
# 1  Radial Velocity       1         874.774   2.21     56.95  2008
# 2  Radial Velocity       1         763.000   2.60     19.84  2011
# 3  Radial Velocity       1         326.030  19.40    110.62  2007
# 4  Radial Velocity       1         516.220  10.50    119.47  2009
# 5  Radial Velocity       1         185.840   4.80     76.39  2008
# 6  Radial Velocity       1        1773.400   4.64     18.15  2002
# 7  Radial Velocity       1         798.500    NaN     21.41  1996
# 8  Radial Velocity       1         993.300  10.30     73.10  2008
# 9  Radial Velocity       2         452.800   1.99     74.79  2010

# %%
# 사용 가능한 폰트 확인
import matplotlib.font_manager as fm

for f in fm.fontManager.ttflist : 
    print(f.name)
# Out:
# DejaVu Sans
# DejaVu Sans
# DejaVu Serif
# STIXSizeOneSym
# cmss10
# DejaVu Sans Display
# cmmi10
# STIXGeneral
# DejaVu Serif
# STIXSizeTwoSym
# DejaVu Sans Mono
# cmsy10
# DejaVu Sans
# DejaVu Sans Mono
# STIXNonUnicode
# DejaVu Sans Mono
# DejaVu Serif Display
# STIXSizeThreeSym
# STIXGeneral
# cmr10
# STIXGeneral
# STIXSizeFiveSym
# STIXNonUnicode
# DejaVu Serif
# STIXSizeFourSym
# DejaVu Serif
# STIXSizeThreeSym
# STIXNonUnicode
# cmex10
# cmtt10
# STIXNonUnicode
# cmb10
# STIXSizeFourSym
# STIXSizeOneSym
# DejaVu Sans Mono
# DejaVu Sans
# STIXGeneral
# STIXSizeTwoSym
# LG Smart UI
# Segoe UI Historic
# Palatino Linotype
# Microsoft Himalaya
# Segoe UI Symbol
# Candara
# Segoe UI
# Candara
# Arial
# Microsoft Tai Le
# Corbel
# Leelawadee UI
# Leelawadee UI
# HCR Dotum
# Microsoft YaHei
# Arial
# Constantia
# Segoe UI
# Nirmala UI
# Microsoft New Tai Lue
# Noto Sans KR
# Symbol
# Segoe UI Emoji
# Courier New
# Sitka Small
# Segoe Script
# Cambria
# Trebuchet MS
# SimSun
# ...

# %%
# Seaborn 스타일 설정
# 방법 1.
sns.set_style("ticks")  # 스타일 테마 설정 # 사용 가능한 테마 : “white“, “dark“, “whitegrid“, “darkgrid“, “ticks”
sns.set_context("notebook") # 문맥에 따라 스타일 크기 조정 # 사용 가능한 context : “paper“ - 논문/출판용, “notebook“ - Jupyter 기본 (기본값), “talk“ – 프레젠테이션용, “poster“ - 포스터 등 대형 디스플레이용
sns.set_palette("pastel6")   # 색상 지정
# 한글 깨짐 방지
plt.rcParams['font.family'] = 'Malgun Gothic'  # '맑은 고딕'이 설치되어 있을 경우
plt.rcParams['axes.unicode_minus'] = False     # 마이너스(-) 부호 깨짐 방지

# 방법 2.
sns.set_theme(
    style = "darkgrid",
    rc = {
        "font.family" : "Malgun Gothic",
        "axes.unicode_minus" : False
    }
)

# %%
# 범주형 데이터 그래프
# countplot
palette = sns.color_palette("pastel")  # 색상 따로(명시적으로) 지정
tips = sns.load_dataset("tips")
sns.countplot(data = tips, x = "day", hue = "sex", palette=palette, alpha=0.7)  # hue: 다른 범주로 그룹화하여 다중 시각화 가능
plt.title("요일별 방문자 수")
plt.grid(linestyle=":")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18952\4177003203.py:5: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.countplot(data = tips, x = "day", hue = "sex", palette=palette, alpha=0.7)

# %%
# barplot
sns.barplot(data=tips, x="day", y="tip", palette=palette, alpha=0.6)

plt.title("요일별 평균 팁 금액")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18952\384407173.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=tips, x="day", y="tip", palette=palette, alpha=0.6)
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18952\384407173.py:2: UserWarning: The palette list has more values (10) than needed (4), which may not be intended.
#   sns.barplot(data=tips, x="day", y="tip", palette=palette, alpha=0.6)

# %%
# displot()
# 히스토그램 + 커널 밀도(kde)
# kde=True로 하면 ked 그래프 그려줌
sns.displot(data=tips, x="total_bill", kde=True, bins=20, palette=palette, color="#60BF79")
plt.title("Total bill")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18952\1156299170.py:4: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   sns.displot(data=tips, x="total_bill", kde=True, bins=20, palette=palette, color="#60BF79")

# %%
# scatter()
# 산점도
sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", palette=palette)
plt.title("Total bill과 tip의 상관관계")
plt.show()
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_18952\4154313351.py:3: UserWarning: The palette list has more values (10) than needed (2), which may not be intended.
#   sns.scatterplot(data=tips, x="total_bill", y="tip", hue="sex", palette=palette)

# %%
# heatmap()
# 상관계수 행렬의 그래프
penguins = sns.load_dataset("penguins")    # bill : 부리  # flipper : 날개
penguins
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
# 상관계수 행렬
corr= penguins.corr(numeric_only=True)
sns.heatmap(corr, annot=True, fmt=".2f", cmap="YlGn", alpha=0.5)
plt.show()

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="body_mass_g", kind='reg')
plt.show()

# 중심: 산점도 + 회귀선 (kind='reg')
# 주변: x/y 변수 각각의 분포 (히스토그램)
# 상관성과 분포를 동시에 확인 가능

# %%
# jointplot()
sns.jointplot(data=penguins, x="flipper_length_mm", y="body_mass_g", kind="hex", alpha=0.7, color="#60BF79")
plt.show()

# %%
sns.jointplot(data=penguins, x="flipper_length_mm", y="body_mass_g", kind="kde", alpha=0.7, color="#f086a5")
plt.show()
